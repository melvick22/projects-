# %%
import pandas as pd
import numpy as np
from math import cos,sin,pi
import matplotlib.pyplot as plt

# %%
melvick = pd.read_excel("/content/drive/MyDrive/dataset/memba.csv.xlsx")
melvick
# Out:
#    Unnamed: 0  TWITTER  INSTAGRAM  Unnamed: 3  FACEBOOK
# 0      memba        12         13         NaN        26
# 1      lewis         9          3         NaN        23
# 2     mageto         6          5         NaN        12
# 3     mwangi         6          9         NaN        74
# 4     jeremy        17          5         NaN         3
# 5      alvis         8         12         NaN         0
# 6     mungai        12         49         NaN        12
# 7      kelvin        9         72         NaN        45
# 8     melvick       18          4         NaN        75
# 9        john       45         14         NaN         4
# 10     omondi       12         12         NaN        12
# 11      david       13         45         NaN         5
# 12       aloo        1         75         NaN         8
# 13       jane        5          2         NaN        14
# 14     mories        0          3         NaN        12
# 15       rose        5          4         NaN        14
# ...

# %%
x=melvick['FACEBOOK']
y=melvick['TWITTER']
z=melvick['INSTAGRAM']
x
# Out:
# 0     26
# 1     23
# 2     12
# 3     74
# 4      3
# 5      0
# 6     12
# 7     45
# 8     75
# 9      4
# 10    12
# 11     5
# 12     8
# 13    14
# 14    12
# 15    14
# 16    18
# 17    13
# 18    15
# 19    14
# 20    14
# 21    13
# Name: FACEBOOK, dtype: int64

# %%
y
# Out:
# 0     12
# 1      9
# 2      6
# 3      6
# 4     17
# 5      8
# 6     12
# 7      9
# 8     18
# 9     45
# 10    12
# 11    13
# 12     1
# 13     5
# 14     0
# 15     5
# 16     4
# 17     0
# 18     4
# 19    52
# 20     7
# 21     2
# Name: TWITTER, dtype: int64

# %%
plt.plot(x,y,'x')

# %%
plt.plot(x,z,'x')
